# %%
marks = (67,87,56,90,67)

# %%
marks[0]
# Out:
# 67

# %%
marks[1]
# Out:
# 87

# %%
marks.count(67)
# Out:
# 2

# %%
marks.index(56)
# Out:
# 2

# %%
marks = list(marks)

# %%
marks
# Out:
# [67, 87, 56, 90, 67]

# %%
marks.append(100)

# %%
dhanRaj_marks = marks.copy()

# %%
dhanRaj_marks[0] = 78

# %%
marks
# Out:
# [67, 87, 56, 90, 67, 100]

# %%
dhanRaj_marks
# Out:
# [78, 87, 56, 90, 67, 100]

# %%
sonu_marks = marks

# %% [markdown]
# wrong way

# %%
sonu_marks[2] =80

# %%
sonu_marks
# Out:
# [67, 87, 80, 90, 67, 100]

# %%
marks
# Out:
# [67, 87, 80, 90, 67, 100]

# %% [markdown]
# more on list

# %%
marks.index(87)
# Out:
# 1

# %%
marks.insert(1,77)

# %%
marks
# Out:
# [67, 77, 87, 80, 90, 67, 100]

# %% [markdown]
# removal

# %%
marks.pop()
# Out:
# 100

# %%
marks.pop(1)
# Out:
# 77

# %%
marks
# Out:
# [67, 87, 80, 90, 67]

# %% [markdown]
# remove by value

# %%
marks.remove(55)

# %%
marks.remove(80)

# %%
marks
# Out:
# [67, 87, 90, 67]

# %%
marks.sort()
marks
# Out:
# [67, 67, 87, 90]

# %%
marks.reverse()
marks
# Out:
# [90, 87, 67, 67]

# %%
marks.clear()

# %%
marks
# Out:
# []

# %% [markdown]
# # **SETS** & dictionary
# unordered dataset

# %%
d = set()

# %%
d.add("aeroplane")

# %%
d
# Out:
# {'aeroplane'}

# %%
primes = {2 ,3,5,7,11,13}

# %%
primes
# Out:
# {2, 3, 5, 7, 11, 13}

# %%
primes.add(11)
primes
# Out:
# {2, 3, 5, 7, 11, 13}

# %%
x = {1,2,1,2,31,23,12,1,231,1,23,12,31,1,23,12,31,23,12,312}
print(x)
# Out:
# {1, 2, 231, 12, 23, 312, 31}

# %%
emps = ["ram","raj","rahul","ram"]

# %%
uni_emp =set(emps)

# %%
uni_emp
# Out:
# {'rahul', 'raj', 'ram'}

# %%
x[2] # error

# %%
for numbers in x:
  print(numbers)
# Out:
# 1
# 2
# 231
# 12
# 23
# 312
# 31

# %%
xl= list(x)

# %%
xl[2]
# Out:
# 231

# %% [markdown]
# functons in **set**

# %%
x = {1,2,3,4}
y = {2,3,4,5}
z = {6,7,8,9}

# %%
x.union(y)
# Out:
# {1, 2, 3, 4, 5}

# %%
x.union(z)
# Out:
# {1, 2, 3, 4, 6, 7, 8, 9}

# %%
x.intersection(y)
# Out:
# {2, 3, 4}

# %%
x.difference(y)
# Out:
# {1}

# %%
x.issubset(y)
# Out:
# False

# %%
x.issuperset(y)
# Out:
# False

# %%
x.pop()
# Out:
# 1

# %%
x.symmetric_difference(z)
# Out:
# {2, 3, 4, 6, 7, 8, 9}

# %%
x2 = {3,4,5,6}

# %%
x
# Out:
# {2, 3, 4}

# %%
x.symmetric_difference(x2)
# Out:
# {2, 5, 6}

# %%
x.union(x2)
# Out:
# {2, 3, 4, 5, 6}

# %%
seq1 = input("give 5 values using spaces")
seq1 = set(seq1.split(" "))
print(seq1)
# Out:
# give 5 values using spaces23 45 23 45 67
# {'23', '45', '67'}
