# %%
x = ['Ravi Prakash',100, 22, 226022, 'Lucknow','Regional manager', True, False]

# %%
data = {'name': 'Ravi Prakash', 'eid': 100,
        'age': 22, 'pincode': 226022, 'city': 'Lucknow',
        'desig' : 'Regional manager', 'is_married': True, 'have_children':True }

# %%
print(data)
# Out:
# {'name': 'Ravi Prakash', 'eid': 100, 'age': 22, 'pincode': 226022, 'city': 'Lucknow', 'desig': 'Regional manager', 'is_married': True, 'have_children': True}

# %%
data['desig']
# Out:
# 'Regional manager'

# %%
data['name']
# Out:
# 'Ravi Prakash'

# %%
data['age'] = 23 # update

# %%
data

# %%
data['dept'] = 'Sales' # adding data

# %%
data

# %%
data.pop('is_married') # remove
# Out:
# True

# %%
print(data)
# Out:
# {'name': 'Ravi Prakash', 'eid': 100, 'age': 23, 'pincode': 226022, 'city': 'Lucknow', 'desig': 'Regional manager', 'have_children': True, 'dept': 'Sales'}

# %%
# basic loop
for i in data:
    print(i)

# %%
# actual loop
for k, v in data.items():
    print(k, v)

# %%
# this also works
for i in data:
    print(i , data[i])
# Out:
# name Ravi Prakash
# eid 100
# age 23
# pincode 226022
# city Lucknow
# desig Regional manager
# have_children True
# dept Sales

# %%
user_data = {}
for i in range(5):
    key = input("enter name? ")
    val = input('enter value=>')
    user_data[key] = val

print(user_data)

# %%
# store student marks in a dict
report = {
    'Raja': {
        'eng' : [50, 80],
        'hindi': [40, 83],
        'maths': [39,59],
    },
    'Rani' :{
        'eng' :[29, 49],
        'hindi': [40,70],
        'maths': [2,1],
    },
}

# %%
report['Raja']['Comp'] = 90
report
# Out:
# {'Raja': {'eng': [50, 80], 'hindi': [40, 83], 'maths': [39, 59], 'Comp': 90},
#  'Rani': {'eng': [29, 49], 'hindi': [40, 70], 'maths': [2, 1]}}

# %%
report['Rani']['hindi'][0]
# Out:
# 40

# %%
for name,marks in report.items():
    print(name)
    for subject, val in marks.items():
        print(f'=>{subject} = {val}')
# Out:
# Raja
# =>eng = [50, 80]
# =>hindi = [40, 83]
# =>maths = [39, 59]
# =>Comp = 90
# Rani
# =>eng = [29, 49]
# =>hindi = [40, 70]
# =>maths = [2, 1]

# %% [markdown]
# wap to create a contact dictionary, which will have some names and phone numbers. The user can search for a name through input. if the name is in the dictionary, then display the phone number else, ask the user to add the number of the person by him/her self.
#
# contact = {
#     'police': 112,
#     'hostpital': 109,
# }

# %%
ord('A')
# Out:
# 65
