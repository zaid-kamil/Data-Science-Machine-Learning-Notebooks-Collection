# %%
import math

# %%
x = -254.63

# %%
math.fabs(x)
# Out:
# 254.63

# %%
math.fabs(math.ceil(x))
# Out:
# 254.0

# %%
x = -3.54554
math.floor(math.fabs(x))
# Out:
# 3

# %%
try:
  name = "alex "
  x = 20
  print('%20s is a bad player %12d'%(name,x))
finally:
  print('hello')
# Out:
#                alex  is a bad player           20
# hello
