# %% [markdown]
# condition in python basically are of three styles
# - **if block**
# - **if else block**
# - **if elif else block**

# %% [markdown]
# python has an indentation system that will help us to create block of code and allow us to write clean and consize code

# %% [markdown]
# ```python|
# statement :
#     something
#     something else
# outside statement
# ```

# %%
# True
if 50 < 200 :
    print("very good")
# Out:
# very good

# %%
# False
if 50 < 40: 
    print("very very good")

# %%
name = input("who is spiderman:")
if name == 'peter parker':
    print(f'{name} is spiderman')
if name == 'Bruce wayne':
    print(f"{name} is actually Batman!!")
if name == 'Clark kent' or name =='clark kent' or name =='Clark Kent':
    print(f'no you dum-dum {name} is superman')
# Out:
# who is spiderman:clark kent
# no you dum-dum clark kent is superman

# %%
age=int(input('what is ur age: '))
if age > 100:
    print("welcome dada ji")
else:
    print('welcome!')
# Out:
# what is ur age: 28
# welcome!

# %%
a = 2
if a > 5:
    print('a is greater than 5')
else:
    print('a is less than 5')
# Out:
# a is less than 5

# %%
salary = int(input("What is the salary of employee: "))
if salary > 5000 and salary <= 10000:
    da = salary * .05       
    print(f'your DA is {da}')
elif salary > 10000 and salary <= 15000:
    da = salary * .075
    print(f'your DA is {da}')
elif salary > 15000 and salary <=25000:
    print('no DA for you, okay')
    print('go home')
elif salary > 25000 and salary <=50000:
    da = salary * .10       
    print(f'your DA is {da}')
# Out:
# What is the salary of employee: 5001
# your DA is 250.05

# %%
name = input('enter your name=>')
email = input('enter your email=>')
password = input('enter your password=>')
cpassword =input('confirm your password=>')

if len(name) > 3:
    if len(email) > 10 and '@' in email and '.com' in email:
        if len(password) > 5 and len(password) <= 20:
            if password == cpassword:
                print('🤩 everything is OK!')
            else:
                print('❌ password do not match')
        else:
            print('❌ password invalid')
    else:
        print('❌ email is invalid')
else:
    print('❌ name is invalid')
