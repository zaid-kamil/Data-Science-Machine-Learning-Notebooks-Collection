# %% [markdown]
# # Builtin functions

# %%
abs?

# %%
abs(-23.32)
# Out:
# 23.32

# %% [markdown]
# ### iterable
# `anything that can be used in loops is iterable`
#
# or
#
# `a variable holding multiple values`

# %%
all?

# %%
x = [1,2,3,4,5]
all(x)
# Out:
# True

# %%
x = [1,2,3,0,0,1]
all(x)
# Out:
# False

# %%
x = ['amar','akbar','']
all(x)
# Out:
# False

# %%
any?

# %%
x= [0,0,0,0]
print(any(x))
x = [0,1,0,0,1]
print(any(x))
# Out:
# False
# True

# %%
bool('hello')
# Out:
# True

# %%
bytes('hello'.encode())
# Out:
# b'hello'

# %%
chr?

# %%
chr(10)
# Out:
# '\n'

# %%
chr(65)
# Out:
# 'A'

# %%
chr(8792)
# Out:
# '≘'

# %%
dir?

# %%
dir(list)

# %%
eval?

# %%
x = 1
y = 2
query = input('create eq using x and y ')
eval(query)
# Out:
# create eq using x and y x**3 + y/10
# 1.2

# %%
eval('x - y // 10 * 15 - x + y')
# Out:
# 2

# %%
help?

# %%
help(tuple)

# %%
type('2')
# Out:
# str

# %%
isinstance?

# %%
isinstance('hello',str)
# Out:
# True

# %%
isinstance('hello',(int,float))
# Out:
# False

# %%
isinstance(2,(int,float))
# Out:
# True

# %%
isinstance(3.5,(int,float))
# Out:
# True

# %%
len([1,2,3,4,5])
# Out:
# 5

# %%
iter?

# %%
next?

# %%
vowels = 'aeiou'
vowel_iter = iter(vowels)

# %%
next(vowel_iter)
# Out:
# 'a'

# %%
next(vowel_iter)
# Out:
# 'e'

# %%
max((1,2,3,34,54,2,312,312,2,23))
# Out:
# 312

# %%
min((1,2,3,34,54,2,312,312,2,23))
# Out:
# 1

# %%
sum((1,2,3,34,54,2,312,312,2,23))
# Out:
# 745

# %%
round(1.32321)
# Out:
# 1

# %%
sorted((1,2,3,34,54,2,312,312,2,23))
# Out:
# [1, 2, 2, 2, 3, 23, 34, 54, 312, 312]

# %%
zip?

# %%
x = [1,2,3,4]
y = [2,3,4,5,6]
for i,j in zip(x,y):
    print(i, j)
# Out:
# 1 2
# 2 3
# 3 4
# 4 5

# %%
open?

# %%
file = open('/content/sample_data/README.md')

# %%
content = file.read()
print(content)

# %%
file.close()

# %%
# closing of file using with keyword 
with open('/content/sample_data/README.md') as file:
    print(file.read())

# %% [markdown]
# # File handling
#
# - `open()` builtin function
# - `os` module usage

# %% [markdown]
# ### reading a file

# %%
with open('/content/sample_data/README.md') as file:
    print(file.read())
# Out:
# This directory includes a few sample datasets to get you started.
#
# *   `california_housing_data*.csv` is California housing data from the 1990 US
#     Census; more information is available at:
#     https://developers.google.com/machine-learning/crash-course/california-housing-data-description
#
# *   `mnist_*.csv` is a small sample of the
#     [MNIST database](https://en.wikipedia.org/wiki/MNIST_database), which is
#     described at: http://yann.lecun.com/exdb/mnist/
#
# *   `anscombe.json` contains a copy of
#     [Anscombe's quartet](https://en.wikipedia.org/wiki/Anscombe%27s_quartet); it
#     was originally described in
#
#     Anscombe, F. J. (1973). 'Graphs in Statistical Analysis'. American
#     Statistician. 27 (1): 17-21. JSTOR 2682899.
#
#     and our copy was prepared by the
#     [vega_datasets library](https://github.com/altair-viz/vega_datasets/blob/4f67bdaad10f45e3549984e17e1b3088c731503d/vega_datasets/_data/anscombe.json).

# %% [markdown]
# ### write data to a file

# %%
newfile = open('file1.txt','w')
newfile.write('The best movies are')
newfile.write(('to be continued...'))
newfile.close() # save and close

# %%
# file will autosave and close after block ends
with open('file1.txt','w') as newfile:
    newfile.write('The best movies are\n')
    newfile.write(('Captain America : Winter Soldier\n'))
    newfile.write(('Avengers Endgame\n'))

# w mode overwrites the file

# %% [markdown]
# ### updating a file with new data

# %%
with open('file1.txt','a') as file:
    file.write('Iron Man\n')
    file.write('Sucide Squad\n')
    file.write('Interstellar\n')

# %% [markdown]
# ### write and read or vice versa in the same session

# %%
file =  open('file1.txt','w+')
file.write('Iron Man\n')
file.write('Sucide Squad\n')
file.write('Interstellar\n')
file.seek(0) # takes the cursor to start of file
print(file.read())
file.close()
# Out:
# Iron Man
# Sucide Squad
# Interstellar

# %%
import os

# %%
os.mkdir('god of war')

# %%
os.rmdir('god of war')

# %% [markdown]
# methods of os module
# - mkdir
# - chdir
# - getcwd
# - rmdir
# - makedirs
# - listdir

# %%
os.getcwd()
# Out:
# '/content'

# %%
os.mkdir('sample_data/abc')

# %%
os.chdir('sample_data/abc')
os.getcwd()
# Out:
# '/content/sample_data/abc'

# %%
os.mkdir('xyz')

# %%
os.listdir()
# Out:
# ['xyz']

# %%
os.chdir('../..')

# %%
os.getcwd()
# Out:
# '/content'

# %%
os.chdir('..')

# %%
os.listdir()
# Out:
# ['sys',
#  'bin',
#  'var',
#  'lib',
#  'lib64',
#  'media',
#  'etc',
#  'boot',
#  'proc',
#  'root',
#  'tmp',
#  'usr',
#  'home',
#  'run',
#  'mnt',
#  'dev',
#  'opt',
#  'srv',
#  'sbin',
#  'content',
#  '.dockerenv',
#  'tools',
#  'datalab',
#  'swift',
#  'dlib-19.18.0-cp36-cp36m-linux_x86_64.whl',
#  'dlib-19.18.0-cp27-cp27mu-linux_x86_64.whl',
#  'tensorflow-1.15.2',
#  'lib32']

# %%
os.listdir('media')
# Out:
# []

# %%
os.listdir('tensorflow-1.15.2')
# Out:
# ['python2.7', 'python3.6']

# %%
filepath = "/abc/xyz/demo.txt"
os.path.exists(filepath)
# Out:
# False

# %%
mnist = '/content/sample_data/mnist_test.csv'
os.path.exists(mnist)
# Out:
# True

# %%
if os.path.exists(mnist):
    print("FILE ADDRESS FOUND")
else:
    print("INVALID ADDRESS")
# Out:
# FILE ADDRESS FOUND

# %%
os.path.exists('/content/sample_data')
# Out:
# True

# %%
os.path.exists('/content/ample_data')
# Out:
# False

# %%
os.path.isdir('/content/sample_data')
# Out:
# True

# %%
os.path.isdir(filepath)
# Out:
# False

# %%
os.path.getsize(mnist) # in bytes
# Out:
# 18289443

# %%
os.path.getsize(mnist) / (1024*1024) # in MB
# Out:
# 17.442172050476074

# %%
os.path.join?

# %%
os.makedirs('hi/there/how/are/you')

# %% [markdown]
# # math and random modules

# %%
import math, random

# %%
math.ceil(10.3435454545)
# Out:
# 11

# %%
math.floor(10.3435454545)
# Out:
# 10

# %%
round(10.3435454545)
# Out:
# 10

# %%
math.fabs(-10.34343)
# Out:
# 10.34343

# %%
math.log(2)
# Out:
# 0.6931471805599453

# %%
math.log2(10)
# Out:
# 3.321928094887362

# %%
math.sin(1)
# Out:
# 0.8414709848078965

# %%
math.factorial(4)
# Out:
# 24

# %%
random.random() # 0 - 1
# Out:
# 0.14280721384190942

# %%
random.randint(1, 20) #  1>=n<=20
# Out:
# 15

# %%
random.randrange(1,20) # 1>=n<20
# Out:
# 6

# %%
pokemon = ['Pickachu','Raichu','Meowth','Onyx','Scyther']

# %%
random.choice(pokemon)
# Out:
# 'Pickachu'

# %%
random.choices(pokemon, k=5)
# Out:
# ['Raichu', 'Onyx', 'Scyther', 'Meowth', 'Pickachu']

# %%
random_10 = [random.randint(1,100) for i in range(10)]
print(random_10)
# Out:
# [23, 62, 84, 36, 49, 91, 82, 63, 74, 97]

# %% [markdown]
# # other modules

# %%
import requests

# %%
requests.get("http://www.wikipedia.org").text

# %%
import collections

# %%
x = [1,2,3,1,23,12,122,21,312,1,213,12,132,132,132,132,12,1,322,13,13,213,123,1]
total_val = collections.Counter(x)

# %%
total_val.most_common()
# Out:
# [(1, 5),
#  (132, 4),
#  (12, 3),
#  (213, 2),
#  (13, 2),
#  (2, 1),
#  (3, 1),
#  (23, 1),
#  (122, 1),
#  (21, 1),
#  (312, 1),
#  (322, 1),
#  (123, 1)]

# %%
import string

# %%
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
garbage_data = "there was _ + 0 kjahd09238-1 -9328-21 () -_@32_(#@!)!"
for char in string.punctuation:
    garbage_data = garbage_data.replace(char,'')
print(garbage_data)
# Out:
# there was   0 kjahd092381 932821  32
