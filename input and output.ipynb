# %%
print("hello")
# Out:
# hello

# %%
print("hi",'How are you')
# Out:
# hi How are you

# %%
print("i",'am','a','coder')
# Out:
# i am a coder

# %%
a = 10
b = 'coins'
print("i purchase this apple using",a,b)
# Out:
# i purchase this apple using 10 coins

# %%
print('i , j , k', 'l')
# Out:
# i , j , k l

# %%
print()

# %%
print("hi")
print("how")
print("are")
print('you?')
# Out:
# hi
# how
# are
# you?

# %%
print("hi")
print()
print("how")
print("are")
print('you?')
# Out:
# hi
#
# how
# are
# you?

# %%
a = "apple"
b = 20

# %%
a # raw output
# Out:
# 'apple'

# %%
print("this is an",a) # formatted output
# Out:
# this is an apple

# %%
print("i purchase this apple using",a,b, sep="-->")
# Out:
# i purchase this apple using-->apple-->20

# %%
print("a","b","c",sep='is')
# Out:
# aisbisc

# %%
print('hi',end='.')
print("monkey",end='!')
# Out:
# hi.monkey!

# %%
a = 10
b = 20
c = a + b
d = a * b

# %%
# with out fstring
print("the value of a =",a,",value of b=",b,",the sum of a+b=",c,",the product of a*b",d)
# Out:
# the value of a = 10 ,value of b= 20 ,the sum of a+b= 30 ,the product of a*b 200

# %%
# with f string
print(f"the value of a = {a}, value of b = {b}, the sum of a+b = {c}, the product of a*b = {d}")
# Out:
# the value of a = 10, value of b = 20, the sum of a+b = 30, the product of a*b = 200
