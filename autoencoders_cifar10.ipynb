# %% [markdown]
# #Implementing a convolutional autoencoder with Keras and TensorFlow

# %%
# %tensorflow_version 2.x
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.layers import Conv2D
from tensorflow.keras.layers import Conv2DTranspose
from tensorflow.keras.layers import LeakyReLU
from tensorflow.keras.layers import Activation
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Reshape
from tensorflow.keras.layers import Input
from tensorflow.keras.models import Model
from tensorflow.keras import backend as K
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.datasets import fashion_mnist,cifar10
import matplotlib.pyplot as plt
import numpy as np
import cv2
import matplotlib

# %%
class ConvAutoencoder:
	
	@staticmethod
	def build(width, height, depth, filters=(64, 32), latentDim=32):
		# initialize the input shape to be "channels last" along with
		# the channels dimension itself
		# channels dimension itself
		inputShape = (height, width, depth)
		#chanDim = -1

		# define the input to the encoder
		inputs = Input(shape=inputShape)
		x = inputs

		# loop over the number of filters
		for f in filters:
			# apply a CONV => RELU => BN operation
			x = Conv2D(f, (3, 3), strides=2, padding="same")(x)
			x = LeakyReLU(alpha=0.2)(x)
			x = BatchNormalization()(x)
	
		# flatten the network and then construct our latent vector
		volumeSize = K.int_shape(x)
		x = Flatten()(x)
		latent = Dense(latentDim)(x)

		# build the encoder model
		encoder = Model(inputs, latent, name="encoder")

		# start building the decoder model which will accept the
		# output of the encoder as its inputs
		latentInputs = Input(shape=(latentDim,))
		x = Dense(np.prod(volumeSize[1:]))(latentInputs)
		x = Reshape((volumeSize[1], volumeSize[2], volumeSize[3]))(x)

		# loop over our number of filters again, but this time in
		# reverse order
		for f in filters[::-1]:
			# apply a CONV_TRANSPOSE => RELU => BN operation
			x = Conv2DTranspose(f, (3, 3), strides=2,
				padding="same")(x)
			x = LeakyReLU(alpha=0.2)(x)
			x = BatchNormalization(axis=chanDim)(x)
		print('decoder',x)
		# apply a single CONV_TRANSPOSE layer used to recover the
		# original depth of the image
		x = Conv2DTranspose(depth, (3, 3), padding="same")(x)
		outputs = Activation("sigmoid")(x)

		# build the decoder model
		decoder = Model(latentInputs, outputs, name="decoder")

		# our autoencoder is the encoder + decoder
		autoencoder = Model(inputs, decoder(encoder(inputs)),name="autoencoder")

		# return a 3-tuple of the encoder, decoder, and autoencoder
		return (encoder, decoder, autoencoder)

# %% [markdown]
# # initialize the number of epochs to train for and batch size

# %%
  EPOCHS = 50
  BS = 20

# %% [markdown]
# # load the Fashion MNIST dataset

# %%
print("[INFO] loading cifar10 MNIST dataset...")
((trainX, _), (testX, _)) = cifar10.load_data()
trainX.shape
# Out:
# [INFO] loading cifar10 MNIST dataset...
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 2s 0us/step
# (50000, 32, 32, 3)

# %% [markdown]
# # using the autoencoder

# %% [markdown]
# add a channel dimension to every image in the dataset, then scale
# the pixel intensities to the range [0, 1]

# %%
trainX = trainX.astype("float32") / 255.0
testX = testX.astype("float32") / 255.0

# %% [markdown]
# # construct our convolutional autoencoder

# %%
print("[INFO] building autoencoder...")
(encoder, decoder, autoencoder) = ConvAutoencoder.build(32, 32, 3)
opt = Adam(lr=1e-3)
autoencoder.compile(loss="mse", optimizer=opt,metrics=['accuracy'])
# Out:
# [INFO] building autoencoder...
# decoder Tensor("batch_normalization_3/Identity:0", shape=(None, 32, 32, 64), dtype=float32)

# %% [markdown]
# # train the convolutional autoencoder

# %%
H = autoencoder.fit(
	trainX, trainX,
	validation_data=(testX, testX),
	epochs=EPOCHS,
	batch_size=BS)
# Out:
# Epoch 1/50
# 2500/2500 [==============================] - 22s 9ms/step - loss: 0.0157 - accuracy: 0.5837 - val_loss: 0.0130 - val_accuracy: 0.5869
# Epoch 2/50
# 2500/2500 [==============================] - 22s 9ms/step - loss: 0.0136 - accuracy: 0.6206 - val_loss: 0.0126 - val_accuracy: 0.6451
# Epoch 3/50
# 2500/2500 [==============================] - 22s 9ms/step - loss: 0.0130 - accuracy: 0.6566 - val_loss: 0.0124 - val_accuracy: 0.6812
# Epoch 4/50
# 2500/2500 [==============================] - 22s 9ms/step - loss: 0.0128 - accuracy: 0.6785 - val_loss: 0.0124 - val_accuracy: 0.6869
# Epoch 5/50
# 2500/2500 [==============================] - 22s 9ms/step - loss: 0.0126 - accuracy: 0.6852 - val_loss: 0.0121 - val_accuracy: 0.6979
# Epoch 6/50
# 2500/2500 [==============================] - 21s 9ms/step - loss: 0.0124 - accuracy: 0.6883 - val_loss: 0.0120 - val_accuracy: 0.7083
# Epoch 7/50
# 2500/2500 [==============================] - 21s 9ms/step - loss: 0.0123 - accuracy: 0.6901 - val_loss: 0.0119 - val_accuracy: 0.6897
# Epoch 8/50
# 2500/2500 [==============================] - 21s 9ms/step - loss: 0.0122 - accuracy: 0.6920 - val_loss: 0.0118 - val_accuracy: 0.7143
# Epoch 9/50
# 2500/2500 [==============================] - 22s 9ms/step - loss: 0.0121 - accuracy: 0.6930 - val_loss: 0.0120 - val_accuracy: 0.7083
# Epoch 10/50
# 2500/2500 [==============================] - 22s 9ms/step - loss: 0.0121 - accuracy: 0.6945 - val_loss: 0.0118 - val_accuracy: 0.7147
# Epoch 11/50
# 2500/2500 [==============================] - 22s 9ms/step - loss: 0.0120 - accuracy: 0.6943 - val_loss: 0.0120 - val_accuracy: 0.7118
# Epoch 12/50
# 2500/2500 [==============================] - 22s 9ms/step - loss: 0.0120 - accuracy: 0.6951 - val_loss: 0.0120 - val_accuracy: 0.7158
# Epoch 13/50
# 2500/2500 [==============================] - 22s 9ms/step - loss: 0.0120 - accuracy: 0.6948 - val_loss: 0.0117 - val_accuracy: 0.7132
# Epoch 14/50
# 2500/2500 [==============================] - 22s 9ms/step - loss: 0.0119 - accuracy: 0.6974 - val_loss: 0.0117 - val_accuracy: 0.7208
# Epoch 15/50
# 2500/2500 [==============================] - 22s 9ms/step - loss: 0.0119 - accuracy: 0.6966 - val_loss: 0.0118 - val_accuracy: 0.7161
# Epoch 16/50
# 2500/2500 [==============================] - 22s 9ms/step - loss: 0.0119 - accuracy: 0.6970 - val_loss: 0.0117 - val_accuracy: 0.7115
# Epoch 17/50
# 2500/2500 [==============================] - 22s 9ms/step - loss: 0.0119 - accuracy: 0.6970 - val_loss: 0.0117 - val_accuracy: 0.7102
# Epoch 18/50
# 2500/2500 [==============================] - 22s 9ms/step - loss: 0.0118 - accuracy: 0.6969 - val_loss: 0.0116 - val_accuracy: 0.7207
# Epoch 19/50
# 2500/2500 [==============================] - 22s 9ms/step - loss: 0.0118 - accuracy: 0.6976 - val_loss: 0.0120 - val_accuracy: 0.6935
# Epoch 20/50
# 2500/2500 [==============================] - 22s 9ms/step - loss: 0.0118 - accuracy: 0.6979 - val_loss: 0.0120 - val_accuracy: 0.6964
# Epoch 21/50
# 2500/2500 [==============================] - 22s 9ms/step - loss: 0.0118 - accuracy: 0.6988 - val_loss: 0.0119 - val_accuracy: 0.7029
# Epoch 22/50
# 2500/2500 [==============================] - 22s 9ms/step - loss: 0.0117 - accuracy: 0.6972 - val_loss: 0.0116 - val_accuracy: 0.7205
# Epoch 23/50
# 2500/2500 [==============================] - 22s 9ms/step - loss: 0.0117 - accuracy: 0.6978 - val_loss: 0.0117 - val_accuracy: 0.7055
# Epoch 24/50
# 2500/2500 [==============================] - 22s 9ms/step - loss: 0.0117 - accuracy: 0.6987 - val_loss: 0.0116 - val_accuracy: 0.7124
# Epoch 25/50
# 2500/2500 [==============================] - 22s 9ms/step - loss: 0.0117 - accuracy: 0.6981 - val_loss: 0.0117 - val_accuracy: 0.7050
# Epoch 26/50
# 2500/2500 [==============================] - 22s 9ms/step - loss: 0.0117 - accuracy: 0.6988 - val_loss: 0.0118 - val_accuracy: 0.7180
# Epoch 27/50
# 2500/2500 [==============================] - 21s 9ms/step - loss: 0.0117 - accuracy: 0.6991 - val_loss: 0.0116 - val_accuracy: 0.7218
# Epoch 28/50
# 2500/2500 [==============================] - 21s 9ms/step - loss: 0.0116 - accuracy: 0.6995 - val_loss: 0.0116 - val_accuracy: 0.7227
# Epoch 29/50
# 2500/2500 [==============================] - 21s 9ms/step - loss: 0.0116 - accuracy: 0.6996 - val_loss: 0.0117 - val_accuracy: 0.7100
# Epoch 30/50
# 2500/2500 [==============================] - 21s 9ms/step - loss: 0.0116 - accuracy: 0.6999 - val_loss: 0.0116 - val_accuracy: 0.7166
# Epoch 31/50
# 2500/2500 [==============================] - 21s 8ms/step - loss: 0.0116 - accuracy: 0.6998 - val_loss: 0.0116 - val_accuracy: 0.7265
# Epoch 32/50
# 2500/2500 [==============================] - 21s 8ms/step - loss: 0.0116 - accuracy: 0.7002 - val_loss: 0.0117 - val_accuracy: 0.7223
# Epoch 33/50
# 2500/2500 [==============================] - 21s 8ms/step - loss: 0.0116 - accuracy: 0.7005 - val_loss: 0.0117 - val_accuracy: 0.7217
# Epoch 34/50
# 2500/2500 [==============================] - 21s 9ms/step - loss: 0.0116 - accuracy: 0.7008 - val_loss: 0.0116 - val_accuracy: 0.7219
# Epoch 35/50
# 2500/2500 [==============================] - 21s 9ms/step - loss: 0.0116 - accuracy: 0.7008 - val_loss: 0.0116 - val_accuracy: 0.7173
# Epoch 36/50
# 2500/2500 [==============================] - 21s 9ms/step - loss: 0.0116 - accuracy: 0.7012 - val_loss: 0.0116 - val_accuracy: 0.7232
# Epoch 37/50
# 2500/2500 [==============================] - 21s 9ms/step - loss: 0.0116 - accuracy: 0.7011 - val_loss: 0.0118 - val_accuracy: 0.6936
# Epoch 38/50
# 2500/2500 [==============================] - 22s 9ms/step - loss: 0.0116 - accuracy: 0.7003 - val_loss: 0.0116 - val_accuracy: 0.7069
# Epoch 39/50
# 2500/2500 [==============================] - 22s 9ms/step - loss: 0.0116 - accuracy: 0.7002 - val_loss: 0.0116 - val_accuracy: 0.7132
# Epoch 40/50
# 2500/2500 [==============================] - 21s 9ms/step - loss: 0.0115 - accuracy: 0.7021 - val_loss: 0.0116 - val_accuracy: 0.7132
# Epoch 41/50
# 2500/2500 [==============================] - 22s 9ms/step - loss: 0.0115 - accuracy: 0.7019 - val_loss: 0.0115 - val_accuracy: 0.7142
# Epoch 42/50
# 2500/2500 [==============================] - 21s 9ms/step - loss: 0.0115 - accuracy: 0.7026 - val_loss: 0.0116 - val_accuracy: 0.7205
# Epoch 43/50
# 2500/2500 [==============================] - 21s 9ms/step - loss: 0.0115 - accuracy: 0.7017 - val_loss: 0.0116 - val_accuracy: 0.7069
# Epoch 44/50
# 2500/2500 [==============================] - 21s 9ms/step - loss: 0.0115 - accuracy: 0.7022 - val_loss: 0.0115 - val_accuracy: 0.7127
# Epoch 45/50
# 2500/2500 [==============================] - 21s 9ms/step - loss: 0.0115 - accuracy: 0.7018 - val_loss: 0.0115 - val_accuracy: 0.7195
# Epoch 46/50
# 2500/2500 [==============================] - 21s 9ms/step - loss: 0.0115 - accuracy: 0.7024 - val_loss: 0.0115 - val_accuracy: 0.7267
# Epoch 47/50
# 2500/2500 [==============================] - 21s 9ms/step - loss: 0.0115 - accuracy: 0.7025 - val_loss: 0.0115 - val_accuracy: 0.7132
# Epoch 48/50
# 2500/2500 [==============================] - 21s 9ms/step - loss: 0.0115 - accuracy: 0.7019 - val_loss: 0.0117 - val_accuracy: 0.7207
# Epoch 49/50
# 2500/2500 [==============================] - 21s 9ms/step - loss: 0.0115 - accuracy: 0.7026 - val_loss: 0.0115 - val_accuracy: 0.7272
# Epoch 50/50
# 2500/2500 [==============================] - 21s 9ms/step - loss: 0.0115 - accuracy: 0.7025 - val_loss: 0.0116 - val_accuracy: 0.7212

# %% [markdown]
# # construct a plot that plots and saves the training history

# %%
N = np.arange(0, EPOCHS)
plt.style.use("ggplot")
plt.figure()
plt.plot(N, H.history["loss"], label="train_loss")
plt.plot(N, H.history["val_loss"], label="val_loss")
plt.title("Training Loss and Accuracy")
plt.xlabel("Epoch #")
plt.ylabel("Loss/Accuracy")
plt.legend(loc="lower left")
plt.savefig("plot.png")

# %% [markdown]
# # use the convolutional autoencoder
#  Make predictions on the testing images, then initialize our list of output images

# %%
print("[INFO] making predictions...")
decoded = autoencoder.predict(testX)
outputs = None
samples=8
# Out:
# [INFO] making predictions...

# %% [markdown]
# # loop over our number of output samples

# %%
for i in range(0, samples):
	# grab the original image and reconstructed image
	original = (testX[i] * 255).astype("uint8")
	recon = (decoded[i] * 255).astype("uint8")

	# stack the original and reconstructed image side-by-side
	output = np.hstack([original, recon])

	# if the outputs array is empty, initialize it as the current
	# side-by-side image display
	if outputs is None:
		outputs = output

	# otherwise, vertically stack the outputs
	else:
		outputs = np.vstack([outputs, output])

# save the outputs image to disk
cv2.imwrite("output.png", outputs)
# Out:
# True

# %%
from PIL import Image
Image.open('/content/output.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=64x256 at 0x7F49B02100B8>
