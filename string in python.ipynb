# %%
my_string = 'hello'
print(my_string)
# Out:
# hello

# %%
my_string = "hello"
print(my_string)
# Out:
# hello

# %%
my_string = '''hello'''
print(my_string)
# Out:
# hello

# %%
my_string = '''hello, welcome to 
            the world of python'''
print(my_string)
# Out:
# hello, welcome to
#             the world of python

# %%
str = 'digipodium'
print( 'str = ', str)
# Out:
# str =  digipodium

# %%
#first character
print('str[0]= ' , str[0])
# Out:
# str[0]=  d

# %%
#second character
print('str[1]= ' , str[1])
# Out:
# str[1]=  i

# %%
#third character
print('str[2] = ' , str[2])
# Out:
# str[2] =  g

# %%
#fourth character
print('str[3] = ' , str[3])
# Out:
# str[3] =  i

# %%
#fifth character
print('str[4] = ' , str[4])
# Out:
# str[4] =  p

# %%
#sixth character
print('str[5] = ' , str[5])
# Out:
# str[5] =  o

# %%
#seventh character
print('str[6] = ' , str[6])
# Out:
# str[6] =  d

# %%
# last fourth character
print('str[4] = ' , str[-4])
# Out:
# str[4] =  d

# %%
# getting a slice
s = 'digipodium'
slice1 = s[4:7]
print(slice1)
slice2 = s[3:len(s)]
print(slice2)
slice3 = s[:4]
print(slice3)
# Out:
# pod
# ipodium
# digi

# %%
# getting a slice
s = 'digipodium'
slice1 = s[4:7]
slice3 = s[4:]
print(slice1)
print(slice3)
# Out:
# pod
# podium

# %%
# 16 million characters

x = chr(65)
print(x)

x = chr(2365)
print(x)

x = chr(12365)
print(x)
# Out:
# A
# ऽ
# き

# %%
y = ord('X')
print(y)
y1 = ord('K')
print(y1)
y2 = ord('Z')
print(y2)
y3 = ord('*')
print(y3)
# Out:
# 88
# 75
# 90
# 42

# %%
print(len('krishna'))
print(len('Army'))
print(len('all is well'))
# Out:
# 7
# 4
# 11

# %%
a = 'apple'
b = 'juice'
ab = a + b
print(ab)
# Out:
# applejuice

# %%
w1 = 'this'
w2 = 'is'
w3 = 'Amazing'
msg = w1 + '' + w2 + ''+ w3
print(msg)
# Out:
# this is Amazing

# %%
word1 = "Tiger"
print(word1 * 10)

word = "INDIA "
print(word *10)
# Out:
# TigerTigerTigerTigerTigerTigerTigerTigerTigerTiger
# INDIA INDIA INDIA INDIA INDIA INDIA INDIA INDIA INDIA INDIA

# %%
for i in range(1,10):
  print(i * ' * ')
# Out:
#  *
#  *  *
#  *  *  *
#  *  *  *  *
#  *  *  *  *  *
#  *  *  *  *  *  *
#  *  *  *  *  *  *  *
#  *  *  *  *  *  *  *  *
#  *  *  *  *  *  *  *  *  *
