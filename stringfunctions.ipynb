# %%
sentence = "Life before death, Hope before despair, Journey before destination"
a = 10
b = 20
c = a + b
colors = ['red','green','blue']
word = "alpha"

# %%
"The famous qoute is {}".format(sentence)
# Out:
# 'The famous qoute is journey before destination'

# %%
"a = {} , b = {} , a + b = {}".format(a,b,c)
# Out:
# 'a = 10 , b = 20 , a + b = 30'

# %% [markdown]
# FORMAT FUNCTION IS OLD AND WE ACTUALLY USE FSTRING..

# %%
f'The famous qoute is {sentence}'
# Out:
# 'The famous qoute is journey before destination'

# %%
f"a = {a} , b = {b} , c = {a + b}"
# Out:
# 'a = 10 , b = 20 , c = 30'

# %%
sentence.split()
# Out:
# ['journey', 'before', 'destination']

# %%
words = sentence.split()
print(words)
print(f'we got {len(words)}')
# Out:
# ['Life', 'before', 'death,', 'Hope', 'before', 'despair,', 'Journey', 'before', 'destination']
# we got 9

# %%
quotes = sentence.split(",")
for q in quotes :
  print(q)
# Out:
# Life before death
#  Hope before despair
#  Journey before destination

# %%
" ".join(colors)   # TO JOIN
# Out:
# 'red green blue'

# %%
" ".join(word)
# Out:
# 'a l p h a'

# %%
" >> ".join(word)
# Out:
# 'a >> l >> p >> h >> a'

# %%
word.strip()      #REMOVES EXTRA SPACE IN BEGINNING
# Out:
# 'alpha'

# %%
clean_word = word.strip()

# %%
clean_word
# Out:
# 'alpha'

# %%
for q in quotes :
  print(q.strip())
# Out:
# Life before death
# Hope before despair
# Journey before destination

# %% [markdown]
# ***USE A QUESTION MARK AFTER THE FUNCTION NAME IN COLAB, TO FIND A MEANING OF A FUNCTION.***

# %%
clean_word.split?

# %%
q
# Out:
# ' Journey before destination'

# %%
q_u = q.upper()
print(q_u)
# Out:
#  JOURNEY BEFORE DESTINATION

# %%
q_l = q.lower()
print(q_l)
# Out:
#  journey before destination

# %%
q_t = q.title()
print(q_t)
# Out:
#  Journey Before Destination

# %%
q_s  = q.swapcase()
print(q_s)
# Out:
#  jOURNEY BEFORE DESTINATION

# %%
sentence
# Out:
# 'Life before death, Hope before despair, Journey before destination'

# %%
sentence.find('hope')      # 20 is  the starting index for he strin we searching.
# Out:
# 20

# %%
sentence.replace('e','o')
# Out:
# 'lifo boforo doath , hopo boforo dospair , journoy boforo dostination'

# %%
sentence.replace('life', 'Code').replace('death', 'sleeping').replace('hope','work').replace('despair','party')
# Out:
# 'Code before sleeping , work before party , journey before destination'

# %%
sentence.count("o")
# Out:
# 6

# %%
sentence.count("before")
# Out:
# 3

# %%
sentence.count("e")
# Out:
# 12

# %%
for word in sentence.split():
  print(word, word.count('e'))
# Out:
# life 1
# before 2
# death 1
# , 0
# hope 1
# before 2
# despair 1
# , 0
# journey 1
# before 2
# destination 1

# %%
name = "LT. KRISHNANAND"
N1 = name.startswith('LT')
N2 = name.startswith('DR')
print(N1) 
print(N2)
# Out:
# True
# False

# %%
msg = 'hi ,this is krishna'
print(msg.endswith('.'))
print(msg.endswith('krihna'))
print(msg.endswith('a'))
# Out:
# False
# False
# True

# %%
if msg.endswith(".") :
  print('NO')
elif msg.startswith("hi"):
   print('YES')
# Out:
# YES
