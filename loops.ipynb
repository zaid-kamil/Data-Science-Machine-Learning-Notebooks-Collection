# %%
name = "John Wick"

# %%
for c in name:
    print(c)

# %%
numbers= [23,45,567,78,8,92,1,34,1,2,33,4]
for n in numbers:
    if n%2 == 0:
        print(n,'even')
    else:
        print(n)
# Out:
# 23
# 45
# 567
# 78 even
# 8 even
# 92 even
# 1
# 34 even
# 1
# 2 even
# 33
# 4 even

# %%
for idx, val in enumerate(name):
    print(idx , val)
# Out:
# 0 J
# 1 o
# 2 h
# 3 n
# 4
# 5 W
# 6 i
# 7 c
# 8 k

# %%
items = ['Apple','CustardApple','Cherry']
prices = [300,250,400]
qtys = [3, 2, 1]

# %%
for data in zip(items,prices,qtys):
    print(data)
# Out:
# ('Apple', 300, 3)
# ('CustardApple', 250, 2)
# ('Cherry', 400, 1)

# %%
for i,p,q in zip(items,prices,qtys):
    print(i, '=', p,'->',q )
# Out:
# Apple = 300 -> 3
# CustardApple = 250 -> 2
# Cherry = 400 -> 1

# %%
option = 1
while option == 1:
    print('welcome to the program')
    print('what you want to do')
    print('1. view message again')
    print('2. close program')
    
    choice =  input('>>>')
    if choice == '1':
        option = 1
    elif choice == '2':
        option = 2
    else:
        print('restarting')

# %%
password = '128932'
while True:
    pwd = input('enter password = ')
    if pwd == password :
        print('welcome')
        break
    else:
        print('try again')
# Out:
# enter password =
# enter password =
# try again
# try again
# enter password =
# try again
# enter password = 17236767
# try again
# enter password = 12873190
# try again
# enter password = 128932
# welcome

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
place = ["Chennai",'Hyderabad','Delhi/NCR','Pune','Bengaluru','Mumbai']
data = [10.3,11.8,11.9,12,14.5,15.7]
label=  'Salaries in Lakhs(INR)'
title = 'Cities with Salaries in AI'

# %%
plt.title(title)
sns.barplot(x=data,y=place,orient=1)
plt.xlabel(label)
plt.show()

# %%
sns.barplot?
