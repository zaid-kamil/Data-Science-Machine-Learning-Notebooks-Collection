# %%
# %tensorflow_version 2.x

# %%
dataset = "/content/drive/My Drive/courses/machine learning with python/machine learning notebooks/ARTIFICIAL NEURAL NETWORKS/Churn_Modelling.csv"

# %%
import pandas as pd
import plotly.express as xp
import numpy as np

# %%
df = pd.read_csv(dataset,index_col ='RowNumber')
df.head()

# %%
df.info()

# %% [markdown]
# # Preprocessing dataset

# %%
from sklearn.preprocessing import LabelEncoder, OneHotEncoder

# %%
geoEncoder = LabelEncoder()
df.Geography = geoEncoder.fit_transform(df.Geography)
df.head()

# %%
geoHotEncoder = OneHotEncoder(categories='auto')
geodummies = geoHotEncoder.fit_transform(df.Geography.values.reshape(-1,1)).toarray()
geodummies

# %%
genderEncoder = LabelEncoder()
df.Gender = genderEncoder.fit_transform(df.Gender)
df.head()

# %%
# drop unnecessary columns
df.drop(['Geography','CustomerId','Surname',],axis=1, inplace=True)

# %%
data = np.append(geodummies[:,:-1], df.values, axis=1) # convert it to numpy adding geodummies n-1 col and the df dataframe

# %%
data.shape # numpy data

# %%
# scaling the data
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

x = data[:,:-1]
y = data[:,-1]
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=.2, random_state = 0)
scale = StandardScaler()
x_train = scale.fit_transform(x_train)
x_test = scale.transform(x_test) # no need to fit data again

# %% [markdown]
# # Coding the Neural Network (finally)

# %%
import tensorflow as tf

# %%
classifier = tf.keras.models.Sequential()
classifier.add(tf.keras.layers.Dense(units=6, activation=tf.keras.activations.relu, input_dim = 11)) # 1st hidden layer require inputs
classifier.add(tf.keras.layers.Dense(units=6, activation=tf.keras.activations.relu)) # 2nd hidden is autoconnected to the previous layer
classifier.add(tf.keras.layers.Dense(units=1 , activation=tf.keras.activations.sigmoid))
classifier.compile(optimizer=tf.keras.optimizers.Adam(), loss=tf.keras.losses.binary_crossentropy, metrics= [tf.keras.metrics.binary_accuracy ])
classifier.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_3 (Dense)              (None, 6)                 72
# _________________________________________________________________
# dense_4 (Dense)              (None, 6)                 42
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 7
# ...
# Total params: 121
# Trainable params: 121
# Non-trainable params: 0
# _________________________________________________________________

# %%
# %load_ext tensorboard
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard

# %%
tensorboard_callback = tf.keras.callbacks.TensorBoard('output/logs', histogram_freq=1)

# %%
classifier.fit(x_train,
               y_train,
               batch_size=100,
               epochs=20,
               callbacks=[tensorboard_callback])
# Out:
# Epoch 1/20
# 80/80 [==============================] - 0s 2ms/step - loss: 0.6677 - binary_accuracy: 0.6645
# Epoch 2/20
# 80/80 [==============================] - 0s 1ms/step - loss: 0.5709 - binary_accuracy: 0.7745
# Epoch 3/20
# 80/80 [==============================] - 0s 1ms/step - loss: 0.5121 - binary_accuracy: 0.7936
# Epoch 4/20
# 80/80 [==============================] - 0s 2ms/step - loss: 0.4849 - binary_accuracy: 0.7964
# Epoch 5/20
# 80/80 [==============================] - 0s 1ms/step - loss: 0.4682 - binary_accuracy: 0.7974
# Epoch 6/20
# 80/80 [==============================] - 0s 1ms/step - loss: 0.4542 - binary_accuracy: 0.8035
# Epoch 7/20
# 80/80 [==============================] - 0s 1ms/step - loss: 0.4414 - binary_accuracy: 0.8095
# Epoch 8/20
# 80/80 [==============================] - 0s 1ms/step - loss: 0.4314 - binary_accuracy: 0.8170
# Epoch 9/20
# 80/80 [==============================] - 0s 2ms/step - loss: 0.4241 - binary_accuracy: 0.8209
# Epoch 10/20
# ...

# %%
# !kill 251

# %% [markdown]
# # predicting the results

# %%
y_pred = classifier.predict(x_test)

# %%
y_pred = y_pred > .5

# %%
y_pred
# Out:
# array([[False],
#        [False],
#        [False],
#        ...,
#        [False],
#        [False],
#        [False]])

# %%
y_pred.tolist()
# Out:
# [[False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [True],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
#  [False],
# ...

# %%
classifier.save('churn_model.h5')

# %% [markdown]
# # loading the model

# %%
saved_classifier = tf.keras.models.load_model('churn_model.h5')

# %%
saved_classifier.predict(x_test) > .5
# Out:
# array([[False],
#        [False],
#        [False],
#        ...,
#        [False],
#        [False],
#        [False]])
