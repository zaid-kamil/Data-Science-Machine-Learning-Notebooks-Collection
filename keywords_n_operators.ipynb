# %%
x = 5

# %%
y = 200

# %%
x += 5

# %%
x
# Out:
# 15

# %%
y = 100

# %%
y *= 3

# %%
y
# Out:
# 300

# %%
x = 5
x +=5
x -=5
x *=5
x /=5
x //= 5
x **= 5

# %%
x
# Out:
# 1.0

# %%
x==y
# Out:
# False

# %%
x == y
# Out:
# False

# %%
a = 10
b = 3

# %%
a == b
# Out:
# False

# %%
a == a
# Out:
# True

# %%
a == 10
# Out:
# True

# %%
a != b
# Out:
# True

# %%
a > b
# Out:
# True

# %%
a < b
# Out:
# False

# %%
a <= b
# Out:
# False

# %%
a >= b
# Out:
# True

# %%
marks = 27
marks > 60 and marks < 70
# Out:
# False

# %%
marks = 30
marks >= 60 and marks <= 70
# Out:
# False

# %%
age = 20
skill = "coding"
age >123 or skill == "coding"
# Out:
# True

# %%
not age == 10
# Out:
# True

# %%
colors = ['red','blue','green']
colors2 = ['red','blue','green']

# %%
colors == colors2
# Out:
# True

# %%
colors is colors
# Out:
# True

# %%
movies = ['Avengers','Dark Knight','Big Hero 6','Black panther','captain america']

# %%
'captain america' in movies
# Out:
# True

# %%
'avengers' in movies # case sensitive
# Out:
# False

# %%
'Avengers' in movies
# Out:
# True

# %%
pokemons= ['Pikachu','Charmander','Charizard','Evee']

# %%
name = input('enter a pokemon name')
name in pokemons
# Out:
# enter a pokemon namejiglipuff
# False

# %%
# display full name
fname = input("enter first name ")
lname = input("enter last name ")
print(fname,lname)
# Out:
# enter first name Kaladin
# enter last name stormblessed
# Kaladin stormblessed

# %%
age = input("enter your age")
age  = int(age) # cast
age >= 18
# Out:
# enter your age31
# True

# %%
1
