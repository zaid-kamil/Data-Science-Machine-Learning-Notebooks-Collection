# %%
value = input("enter something: ")
if value.isalnum():  
    print("good")
else:
    print("try again")
# Out:
# enter something: abc 123
# try again

# %%
word = "YES"
word2 = "yes"
if word.isupper():
    print("Good")
if word2.isupper():
    print("good")
# Out:
# Good

# %%
a = 10

# %%
type(a)
# Out:
# int

# %%
type(word)
# Out:
# str

# %%
len(word)
# Out:
# 3

# %%
len("encylopedia")
# Out:
# 11

# %%
chr(65)
# Out:
# 'A'

# %%
chr(90)
# Out:
# 'Z'

# %%
for i in range(100):
    print(i, chr(i))

# %%
chr(838)
# Out:
# '͆'

# %%
ord("A")
# Out:
# 65

# %%
msg = "HELLO WORLD"
for c in msg:
    print(ord(c), end=' ')
# Out:
# 72 69 76 76 79 32 87 79 82 76 68

# %%
# wap to remove all vowels in a string
word = "encylopedia is boring and awesome at the same time"

for v in "aeiou":
    word =  word.replace(v,'')
print(word)
# Out:
# ncylpd s brng nd wsm t th sm tm
