# %%
sentence = "Life before death, Hope before despair, Journey before destination"
a = 10
b = 20
c = a + b
colors = ['red', 'green','blue']
word = " alpha "

# %% [markdown]
# format mixes string with variables

# %%
"the famous quote is {}".format(sentence)
# Out:
# 'the famous quote is Journey before destination'

# %%
"a = {}, b = {} and a + b = {}".format(a,b,c)
# Out:
# 'a = 10, b = 20 and a + b = 30'

# %% [markdown]
# format function is old and now we actually use fstring

# %%
f'the famous quote is {sentence}'
# Out:
# 'the famous quote is Journey before destination'

# %%
f"a = {a}, b = {b} and a + b = {c}"
# Out:
# 'a = 10, b = 20 and a + b = 30'

# %%
sentence.split()
# Out:
# ['Journey', 'before', 'destination']

# %%
words = sentence.split()
print(words)
print(f'we got {len(words)} words')
# Out:
# ['Life', 'before', 'death,', 'Hope', 'before', 'despair,', 'Journey', 'before', 'destination']
# we got 9 words

# %%
quotes = sentence.split(',')
for q in quotes:
    print(q)
# Out:
# Life before death
#  Hope before despair
#  Journey before destination

# %%
" ".join(colors)
# Out:
# 'red green blue'

# %%
"-".join(colors)
# Out:
# 'red-green-blue'

# %%
"_".join(colors)
# Out:
# 'red_green_blue'

# %%
">>>".join(colors)
# Out:
# 'red>>>green>>>blue'

# %%
clean_word = word.strip()

# %%
clean_word
# Out:
# 'alpha'

# %%
for q in quotes:
    print(q.strip())
# Out:
# Life before death
# Hope before despair
# Journey before destination

# %% [markdown]
# use a question mark after the function name in colab, to find the meaning of that function

# %%
clean_word.split?

# %%
q
# Out:
# ' Journey before destination'

# %%
q.upper()
# Out:
# ' JOURNEY BEFORE DESTINATION'

# %%
q_u = q.upper()
print(q_u)
# Out:
#  JOURNEY BEFORE DESTINATION

# %%
q_l = q.lower()
print(q_l)
# Out:
#  journey before destination

# %%
q_t = q.title()
print(q_t)
# Out:
#  Journey Before Destination

# %%
q_s = q.swapcase()
print(q_s)
# Out:
#  jOURNEY BEFORE DESTINATION

# %%
q = q.strip()
q_c = q.capitalize()
print(q_c)
# Out:
# Journey before destination

# %%
sentence
# Out:
# 'Life before death, Hope before despair, Journey before destination'

# %%
sentence.find('Hope') # 19 is the starting index for the string we are searching
# Out:
# 19

# %%
sentence.find('hope') # -1 means the string is not found in searched string
# Out:
# -1

# %%
sentence.replace('before','after')
# Out:
# 'Life after death, Hope after despair, Journey after destination'

# %%
sentence.replace('e','o')
# Out:
# 'Lifo boforo doath, Hopo boforo dospair, Journoy boforo dostination'

# %%
sentence.replace('z','x') # nothing replace
# Out:
# 'Life before death, Hope before despair, Journey before destination'

# %%
sentence.replace('Life','code')
# Out:
# 'code before death, Hope before despair, Journey before destination'

# %%
# chaining example
output = sentence.replace("Life","Code").replace('death','sleeping').replace('Hope','party').replace('despair','work')
print(output)
# Out:
# Code before sleeping, party before work, Journey before destination

# %%
sentence
# Out:
# 'Life before death, Hope before despair, Journey before destination'

# %%
sentence.count('o')
# Out:
# 6

# %%
sentence.count('before')
# Out:
# 3

# %%
for word in sentence.split():
    print(word, word.count('e'))
# Out:
# Life 1
# before 2
# death, 1
# Hope 1
# before 2
# despair, 1
# Journey 1
# before 2
# destination 1

# %%
name = "Mr. Gopal"
name.startswith('Mr')
# Out:
# True

# %%
name.startswith('Dr')
# Out:
# False

# %%
name.startswith('Super')
# Out:
# False

# %%
"superman".startswith('super')
# Out:
# True

# %%
msg = "hi there"
print(msg.endswith('.'))
# Out:
# False

# %%
if msg.endswith('.'):
    print('You know grammer ✔')
else:
    print('do you know grammer❔')
# Out:
# do you know grammer❔
