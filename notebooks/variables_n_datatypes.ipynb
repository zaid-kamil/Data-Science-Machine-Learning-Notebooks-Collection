# %%
name = 'Zaid Kamil'
city = 'lucknow'
age = 30
fav_color = 'orange'
fav_fruit = 'mango'
price = 130.50
is_code_fun = True

# %%
name
# Out:
# 'Zaid Kamil'

# %%
city
# Out:
# 'lucknow'

# %%
fav_color
# Out:
# 'orange'

# %%
age
# Out:
# 30

# %%
capital
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-630402fa9acd> in <module>()
# ----> 1 capital
#
# NameError: name 'capital' is not defined

# %%
price
# Out:
# 130.5

# %%
price = 1000

# %%
price
# Out:
# 1000

# %%
a = 10
b = 50
c = a + b

# %%
c
# Out:
# 60

# %%
x = 10
y = 20
xy = x * y / 2 * x + 3
xy
# Out:
# 1003.0

# %%
movie1 = "Batman"
movie2 = "Avengers"
movie3 = "Black Panther"

# %%
sum([1,2,3,4,5,6,7,12,31,23,123,12,])
# Out:
# 229

# %%
print
# Out:
# <function print>

# %%
print('i like these movies')
print(movie1, movie2, movie3)
# Out:
# i like these movies
# Batman Avengers Black Panther

# %%
hero = "Superman"
villain = "Darksied"
story = "the hero is very powerfull and strong, but villain is also very strong."
print(story,'hero is',hero,', villain is',villain,', their battle is going to be legendary!')
# Out:
# the hero is very powerfull and strong, but villain is also very strong. hero is Superman , villain is Darksied , their battle is going to be legendary!

# %%
# bonus
import requests
from PIL import Image

imgdata = requests.get('https://i.ytimg.com/vi/32Sgp5aDyGs/mqdefault.jpg',stream=True)
Image.open(imgdata.raw)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=320x180 at 0x7FEEEA357590>

# %% [markdown]
# # put some information in variable about you (atleast 10 variable)

# %%
fruit = "apples"
quantity = 10
print("i have",quantity,fruit)
# Out:
# i have 10 apples

# %% [markdown]
# # data types

# %%
a = 20

# %%
a
# Out:
# 20

# %%
type(a)
# Out:
# int

# %%
city = 'lucknow'
type(city)
# Out:
# str

# %%
city.upper() # data type help us to understand what functionality we can use
# Out:
# 'LUCKNOW'

# %%
pi = 3.145
are_u_fine = True
price = None

# %%
print(type(pi) , type(are_u_fine), type(price))
# Out:
# <class 'float'> <class 'bool'> <class 'NoneType'>

# %%
books = ["The final empire",'Legion','Steelheart','The way of the kings']

# %%
type(books)
# Out:
# list

# %%
movies = []

# %%
ratings = (5,5,3,5,2,1,4)
type(ratings)
# Out:
# tuple

# %%
fruits = {'apple','banana','mango'}
vegs = {"potato",'tomato','brinjal'}

# %%
type(vegs)
# Out:
# set

# %%
info = {
    'amber':'a color similer to yellow and orange',
    'india':'A large country in Asia',
    'username':'alyx',
}

# %%
type(info)
# Out:
# dict

# %%
20000 + 1500
# Out:
# 21500

# %%
12/5
# Out:
# 2.4

# %%
10 / 7
# Out:
# 1.4285714285714286

# %%
10 % 7
# Out:
# 3

# %%
10 // 7
# Out:
# 1

# %%
10 ** 3
# Out:
# 1000

# %%
2 ** 64
# Out:
# 18446744073709551616

# %%
1000 **9023
# Out:
# ...
