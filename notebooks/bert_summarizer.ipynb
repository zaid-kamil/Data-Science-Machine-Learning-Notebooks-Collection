# %%
# !pip install bert-extractive-summarizer

# %%
# !pip install tensorflow==2 grpcio==1.24.3 google-auth

# %%
from summarizer import Summarizer

# %%
body ='''
We believe that privacy is important. This page describes the types of information we receive and collect when you use Rexa, as well as how it is used, and your choices.

Data we gather
In order to encourage responsible editing of Rexa data by users, all users must register with an email address, and login with a password in order to use Rexa. Cookies and other technologies are used to enhance your online experience and improve the quality of our services. Rexa servers automatically record when you visit the web site, including the URL, IP address, browser type, and date and time of your request. We may choose to present links in the form of a "URL redirector"; when this site uses a URL redirector, if you click on a URL, information about that click is sent to Rexa, and Rexa in turn sends you to the site you clicked on. We encourage users to enter various information in order to enhance the services we are able to provide to you, and improve citation and author coreference. Information is also spidered and extracted from public Web pages, PDF and PS files. We may combine information collected from you with information from other sources such as these. We also record other data entered by users, including tags, notes, edits to Rexa data, etc.

Uses
We use this information to provide the services you have requested, including services that display customized content. We also analyze this data for trends, statistics and security, in order to improve our technologies and services. We may use URL redirector information to understand and improve Rexa. For example, we may use this information to determine how often various features are used. Since Rexa is a collaborative system, much of the user-entered data, including tags and notes, are also browsable by other users. Usage data may also be made browsable, for example to list the most visited papers and authors. We may also share this and other information with third parties, including when complying with legal process, preventing fraud or imminent harm, and ensuring the security of our network and services.

Your choices
We offer you choices when we ask for personal information, whenever possible. The primary information that is required for use of Rexa is a valid email address. You may decline to provide further personal information to us and/or refuse cookies in your browser, although some of our features or services may not function properly as a result.

Terms
We reserve the right to terminate anyone's Rexa account, for example, for inappropriate editing of Rexa data.

If you have any questions, please contact us by email. This privacy statement does not extend to anything that is inherent in the operation of the Internet or beyond our control, and is not to be applied in any manner contrary to applicable laws, rules or regulations. By using this site, you consent to the collection and use of your information as we have outlined herein.
'''

# %%
model = Summarizer()

# %%
result = model(body)

# %%
print(result)
# Out:
# This page describes the types of information we receive and collect when you use Rexa, as well as how it is used, and your choices. We encourage users to enter various information in order to enhance the services we are able to provide to you, and improve citation and author coreference. We may combine information collected from you with information from other sources such as these. For example, we may use this information to determine how often various features are used. Terms
# We reserve the right to terminate anyone's Rexa account, for example, for inappropriate editing of Rexa data.

# %%
data ='''When you’re getting started with a machine learning (ML) project, one critical principle to keep in mind is that data is everything. It is often said that if ML is the rocket engine, then the fuel is the (high-quality) data fed to ML algorithms. However, deriving truth and insight from a pile of data can be a complicated and error-prone job. To have a solid start for your ML project, it always helps to analyze the data up front, a practice that describes the data by means of statistical and visualization techniques to bring important aspects of that data into focus for further analysis. During that process, it’s important that you get a deep understanding of: 

The properties of the data, such as schema and statistical properties;

The quality of the data, like missing values and inconsistent data types;

The predictive power of the data, such as correlation of features against target.

This process lays the groundwork for the subsequent feature selection and engineering steps, and it provides a solid foundation for building good ML models. 

There are many different approaches to conducting exploratory data analysis (EDA) out there, so it can be hard to know what analysis to perform and how to do it properly. To consolidate the recommendations on conducting proper EDA, data cleaning, and feature selection in ML projects, we’ll summarize and provide concise guidance from both intuitive (visualization) and rigorous (statistical) perspectives. Based on the results of the analysis, you can then determine corresponding feature selection and engineering recommendations. You can also get more comprehensive instructions in this white paper.

You can also check out the Auto Data Exploration and Feature Recommendation Tool we developed to help you automate the recommended analysis, regardless of the scale of the data, then generate a well-organized report to present the findings. 

EDA, feature selection, and feature engineering are often tied together and are important steps in the ML journey. With the complexity of data and business problems that exist today (such as credit scoring in finance and demand forecasting in retail), how the results of proper EDA can influence your subsequent decisions is a big question. In this post, we will walk you through some of the decisions you’ll need to make about your data for a particular project, and choosing which type of analysis to use, along with visualizations, tools, and feature processing.

Let’s start exploring the types of analysis you can choose from. '''
print('total word:',len(data))
result = model(data,max_length=300)
print('summarized word',len(result))
print(result)
# Out:
# total word: 2538
# summarized word 488
# When you’re getting started with a machine learning (ML) project, one critical principle to keep in mind is that data is everything. You can also check out the Auto Data Exploration and Feature Recommendation Tool we developed to help you automate the recommended analysis, regardless of the scale of the data, then generate a well-organized report to present the findings. EDA, feature selection, and feature engineering are often tied together and are important steps in the ML journey.
