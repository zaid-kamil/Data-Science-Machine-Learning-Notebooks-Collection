# %% [markdown]
# welcome to the first coding class

# %%
import this

# %%
name = "Zaid kamil"

# %%
name
# Out:
# 'Zaid kamil'

# %%
age =29

# %% [markdown]
# 1.   integer `int`
# 2.   float `float`
# 3.   string `str`
# 4.   boolean `bool`
# 5.   Nonetype `None`
# 6.   List `list`
# 7.   Tuple `tuple`
# 8.   Set `set`
# 9.   Dictionray  `dict`

# %%
a = 10
b = 20
c = a + b
c
# Out:
# 30

# %%
print('the number is stored in a')
# Out:
# the number is stored in a

# %%
print('the total money lost at sea is 5billion')
# Out:
# the total money lost at sea is 5billion

# %%
college = input('enter college name:')
# Out:
# enter college name:the musical high

# %%
college
# Out:
# 'the musical high'

# %%
type(a)
# Out:
# int

# %%
type(college)
# Out:
# str

# %%
a = input('enter a num:')
b = input('enter another num:')
print(a + b)
# Out:
# enter a num:100
# enter another num:200
# 100200

# %%
a = int(input('enter a num:'))
b = int(input('enter another num:'))
print(a + b)
# Out:
# enter a num:32930239021930123
# enter another num:19381923183129891289123231
# 19381923216060130311053354

# %% [markdown]
# ### the 5 ways to print formatted output in python
# 1. using comma system
# 2. concatenation of content
# 3. format specifier using format string
# 4. using format() method
# 5. using f-strings ✓

# %%
name= "Hugh"
age = 43
surname = 'Jackman'

# %%
print('my name is',name,surname,'and i am',age,'year old')
# Out:
# my name is Hugh Jackman and i am 43 year old

# %%
print('My name is %s %s and i m %d year old'%(name,surname,age))
# Out:
# My name is Hugh Jackman and i m 43 year old

# %%
print('my name is '+name+" "+surname+' and i am '+str(age)+' year old') # the difficult one
# Out:
# my name is Hugh Jackman and i am 43 year old

# %%
print('my name is {} {} and i am {}'.format(name, surname, age)) # until 3.5 python version
# Out:
# my name is Hugh Jackman and i am 43

# %%
print('my name is {name} {surname} and i am {age}') # nothing happens because python needs to know where are variables
# Out:
# my name is {name} {surname} and i am {age}

# %%
print(f'my name is {name} {surname} and i am {age}') # whatever is in braces is treated as variables
# Out:
# my name is Hugh Jackman and i am 43

# %% [markdown]
# ### math and others operations

# %%
10 + 3 # addition
# Out:
# 13

# %%
10 - 3 # substraction
# Out:
# 7

# %%
10 / 3 # division (float or accurate)
# Out:
# 3.3333333333333335

# %%
10 // 3 # integer divide (gives us quotient)
# Out:
# 3

# %%
10 % 3 # modulus or remainder
# Out:
# 1

# %%
10 * 3 # multiplication
# Out:
# 30

# %%
10 ** 3 # exponent
# Out:
# 1000

# %% [markdown]
# conditional operators

# %%
10 > 3 # greater than
# Out:
# True

# %%
10 < 3 # less than
# Out:
# False

# %%
10  == 10 # equals to
# Out:
# True

# %%
10 != 3 # not equals to
# Out:
# True

# %%
print(10 >= 3)
print(10 <= 3)
# Out:
# True
# False

# %% [markdown]
# logical operators
# - and
# - or
# - not

# %%
10 > 3 and 10 > 5 # if both are True then give True else False
# Out:
# False

# %%
10 > 3 or 10 < 5 # if any one condition is True then give True else False
# Out:
# True

# %%
not 10 == 13
# Out:
# True

# %% [markdown]
# displaying multiple lines

# %%
print('Courage before fear')
print('Life before death')
print('Journey before Destination')
# Out:
# Courage before fear
# Life before death
# Journey before Destination

# %%
print('Johnny Johnny, yes papa\n\nEating sugar, no papa\n\nTelling a lie, no papa\n\nOpen your mouth, hahaha ')
# Out:
# Johnny Johnny, yes papa
#
# Eating sugar, no papa
#
# Telling a lie, no papa
#
# Open your mouth, hahaha

# %% [markdown]
# #### wap to calculate the bill at the restaurant

# %%
item1  = input('enter 1st item : ')
price1 = int(input('enter 1st item price : '))
item2  = input('enter 2nd item : ')
price2 = int(input('enter 2nd item price : '))
item3  = input('enter 3rd item : ')
price3 = int(input('enter 3rd item price : '))
print("Bill :")
print(f'{item1}:{price1}')
print(f'{item2}:{price2}')
print(f'{item3}:{price3}')
total = price1 + price2 + price3
print(f'total cost is {total}')
print(f'GST tax : 30%')
print(f'Amount to be paid : {total + total *.3}')
# Out:
# enter 1st item : Cheese Pasta
# enter 1st item price : 350
# enter 2nd item : Chicken Pizza
# enter 2nd item price : 500
# enter 3rd item : Coke
# enter 3rd item price : 100
# Bill :
# Cheese Pasta:350
# Chicken Pizza :500
# Coke:100
# total cost is 950
# GST tax : 30%
# Amount to be paid : 1235.0

# %% [markdown]
# wap a program to ask an employee the basic salary and calculate
# - HRA which is 10% of basic
# - DA which is 7% of basic
# - TA whihc is 8% of basic
# - TotalSalary which is sum of `basic + da + ta + hra - 3000`
#
# hint-
# - `da is 7% of basic`
# - `da = basic * .07`
