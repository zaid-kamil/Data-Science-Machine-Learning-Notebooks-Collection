# %%
a = 25
if a > 10 :
    print("Hurray")
# Out:
# Hurray

# %%
name = input("enter you username :")
if name == 'admin':
    print("welcome to the application")
# Out:
# enter you username :admin
# welcome to the application

# %%
a = int(input('enter A:'))
b = int(input('enter B:'))
if a > b:
    total = a+b
    print(f'total={total}')
print('the end of code')
# Out:
# enter A:15
# enter B:20
# the end of code

# %%
name = 'spiderman'
age = 17
year = 2019

if name =='spiderman' and age == 17 and year == 2019:
    print("hurray")
# Out:
# hurray

# %%
if name =='spiderman':
    if age == 17:
        if year == 2019:
            print("hurray")
# Out:
# hurray

# %%
if a == 10:
    print('yes')
else:
    print('no')
# Out:
# no

# %%
choice = input('select you fav fruit:')
if choice =='apple':
    print("an apple a day keep the doctor away")
elif choice == 'grapes':
    print("angoor khatte h!")
elif choice == 'banana':
    print("a banana a day keeps hunger away")
else:
    print("sab apni apni pasand hoti h")
# Out:
# select you fav fruit:mango
# sab apni apni pasand hoti h

# %% [markdown]
# ternary operator

# %%
a =  101

# %%
result = "100%" if a == 100 else "not good"

# %%
print(result)
# Out:
# not good

# %%
name = input('who are you? hero or villain:')
task = ("Attack the villain","Help the hero")[name=='hero']
print(task)
# Out:
# who are you? hero or villainvillain
# Attack the villain

# %%
marks = int(input('how much marks did u get in hindi? '))
response = ("Please work hard", "Well done!!!")[marks >=75]
print(response)
# Out:
# how much marks did u get in hindi? 24
# Please work hard

# %% [markdown]
# # python does not have a switch case concept

# %%
#question
print("the monster was 100\" inches long ")
# Out:
# the monster was 100" inches long

# %%
print('the monster was 100" inches long ')
# Out:
# the monster was 100" inches long

# %%
print('where\'s the gift')
# Out:
# where's the gift

# %%
print("where's the action")
# Out:
# where's the action
