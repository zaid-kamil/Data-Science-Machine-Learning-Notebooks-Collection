# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# %%
query = 'speakers'
page = 1
datalist = [] # empty

# %%
link = f'https://www.flipkart.com/search?q={query}&page={page}'

# %%
def getpage(link):
    try:
        page = requests.get(link)
        print('data loaded')
        return BeautifulSoup(page.text,'lxml')
    except Exception as error:
        print('Error',error)

# %%
def extract(pagedata):
    cards =  soup.find_all('div',{'class':'_4ddWXP'})
    size = len(cards)
    if size > 0: # if products are found
        for pr in cards: # pr is single product
            name = pr.find('a',{'class':'s1Q9rs'}).text
            price = pr.find('div',{'class':'_30jeq3'}).text[1:] # start from 2 char
            try: 
                rating = pr.find('div',{'class':'_3LWZlK'}).text
            except:
                rating = 0
            datalist.append({
                'name':name,
                'price':price,
                'rating':rating
            })
        return True
    else:
        print('no product found')
        return False

# %%
def save(filename):
    df = pd.DataFrame(datalist)
    df.to_csv(f'{filename}.csv')
    return df
    print('saved')

# %% [markdown]
# testing time

# %%
page = 1
query = 'controllers'
datalist = [] # empty
while True:
    link = f'https://www.flipkart.com/search?q={query}&page={page}'
    print('extracting data from page :',page)
    soup = getpage(link)
    if soup:                                # if we get page data
        status =  extract(soup)
        if not status:
            print('products extracted')
            break
        else:
            page += 1
# Out:
# extracting data from page : 1
# data loaded
# extracting data from page : 2
# data loaded
# extracting data from page : 3
# data loaded
# extracting data from page : 4
# data loaded
# extracting data from page : 5
# data loaded
# extracting data from page : 6
# data loaded
# extracting data from page : 7
# data loaded
# extracting data from page : 8
# data loaded
# extracting data from page : 9
# data loaded
# extracting data from page : 10
# data loaded
# no product found
# products extracted

# %%
out = save('flipkart_controller_prices')

# %%
out
# Out:
#                                                   name  price rating
# 0              Quantum QHM7468-2V USB GAMEPAD  Gamepad    530    3.6
# 1    BUY SURETY New Arrival Six Finger All-in-One M...    229    3.3
# 2    Amkette Evo Gamepad Pro 4 with Instant Play Bl...  2,099    3.3
# 3       Amkette EvoFox Elite Pro Wireless USB  Gamepad  1,599      4
# 4        Microsoft Wireless Controller Bt Wht  Gamepad  5,199    4.6
# ..                                                 ...    ...    ...
# 355  Pooja COMPATIBLE TO VIDEOCON D2H HD RF REMOTE ...    519    4.2
# 356  The Nile Onion Black Seed Hair Oil Preventing ...    399      0
# 357  COOLCOLD Wireless Optical Gaming Mouse 2.4Ghz ...    329    3.8
# 358            RADANYA Mathematics RDPD-03-71 Mousepad    120    4.6
# 359  Casemaker Have A Nice Day Printed Designer Mou...    198    4.7
#
# [360 rows x 3 columns]

# %% [markdown]
# installing plotly

# %%
# !pip install plotly

# %% [markdown]
# visualization

# %%
import plotly.express as px

# %%
out.rating = out.rating.astype(float) # updating rating values to float

# %%
out.sort_values(by='rating',inplace=True)

# %%
px.bar_polar(out,r='rating',hover_name=out.name,)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="0471719b-5113-4aca-bc4d-26ef2ae136b9" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("0471719b-5113-4aca-bc4d-26ef2ae136b9")) {
#                     Plotly.newPlot(
#                         '0471719b-5113-4aca-bc4d-26ef2ae136b9',
#                         [{"hoverlabel": {"namelength": 0}, "hovertemplate": "<b>%{hovertext}</b><br><br>rating=%{r}", "hovertext": ["Xanova Deimos Large Mousepad", "The Nile 100 % Pure and Natural Organic Sesame Oil for ...", "LIFEMUSIC High Best New Game Controller Gamepad Trigger...", "TIZUM Mouse Pad for Laptop, Notebook, MacBook Pro Air, ...", "Xanova Deimos Large Mousepad", "N K STAR Wireless mouse Wireless Optical  Gaming Mouse", "DEALZIA 6 in 1 2.4G Wireless Game Controller Gamepad Ga...", "Xanova Deimos Extra Large Mousepad", "The Nile Moroccan Argan Hair Oil Pure Cold Pressed Blen...", "Xanova Deimos Extra Large Mousepad", "Oye Stuff Geometric Pattern Printed