# %%
# !pip install bar_chart_race

# %%
import bar_chart_race as bcr

# %%
df = bcr.load_dataset('covid19_tutorial')

# %%
df
# Out:
#             Belgium  China  France  ...  Spain    USA  United Kingdom
# date                                ...
# 2020-04-03     1143   3326    6520  ...  11198   7418            3611
# 2020-04-04     1283   3330    7574  ...  11947   8387            4320
# 2020-04-05     1447   3333    8093  ...  12641   9489            4943
# 2020-04-06     1632   3335    8926  ...  13341  10783            5385
# 2020-04-07     2035   3335   10343  ...  14045  12798            6171
# 2020-04-08     2240   3337   10887  ...  14792  14704            7111
# 2020-04-09     2523   3339   12228  ...  15447  16553            7993
# 2020-04-10     3019   3340   13215  ...  16081  18595            8974
# 2020-04-11     3346   3343   13851  ...  16606  20471            9892
# 2020-04-12     3600   3343   14412  ...  17209  22032           10629
#
# [10 rows x 10 columns]

# %%
bcr.bar_chart_race(df)
# Out:
# <video width="964" height="504" controls autoplay loop>
#   <source type="video/mp4" src="...

# %%
bcr.bar_chart_race(df, orientation='v')
# Out:
# <video width="914" height="554" controls autoplay loop>
#   <source type="video/mp4" src="...

# %%
bcr.bar_chart_race(df, sort='asc')
# Out:
# <video width="964" height="504" controls autoplay loop>
#   <source type="video/mp4" src="...

# %%
bcr.bar_chart_race(df, n_bars=5)
# Out:
# <video width="964" height="504" controls autoplay loop>
#   <source type="video/mp4" src="...

# %%
bcr.bar_chart_race(df, fixed_order=['Iran','USA','Italy','Spain','Belgium'])
# Out:
# <video width="910" height="504" controls autoplay loop>
#   <source type="video/mp4" src="...

# %%
bcr.bar_chart_race(df, steps_per_period=20, period_length=1000)
# Out:
# <video width="964" height="504" controls autoplay loop>
#   <source type="video/mp4" src="...

# %%
bcr.bar_chart_race(df, bar_kwargs={'alpha':.6,'lw':3,'ec':'black'})
# Out:
# <video width="964" height="504" controls autoplay loop>
#   <source type="video/mp4" src="...

# %%
bcr.bar_chart_race(df,bar_label_size=14)
# Out:
# <video width="964" height="504" controls autoplay loop>
#   <source type="video/mp4" src="...

# %%
def summary(values,rank):
  total_deaths=int(values.sum())
  s = f'Total Deaths : {total_deaths}'
  return {'x':.99,'y':.05,'ha':'right','s':s,'size':8}

# %%
bcr.bar_chart_race(df,period_summary_func=summary)
# Out:
# <video width="964" height="504" controls autoplay loop>
#   <source type="video/mp4" src="...

# %%
df = bcr.load_dataset()

# %%
bcr.bar_chart_race(df)
# Out:
# <video width="962" height="504" controls autoplay loop>
#   <source type="video/mp4" src="...

# %% [markdown]
# # Rules for Creating a Bar Chart Race
# - every row should contain a diffrent period (time) and it should be in sequence
# - every column should contain number with different values
# - date should be the first column

# %%
df
