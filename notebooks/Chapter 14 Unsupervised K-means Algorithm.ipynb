# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import plotly.express as px
plt.style.use('ggplot')

# %%
df = pd.read_csv('/content/drive/My Drive/courses/data analytics basics/datasets/Mall_Customers.csv')

# %%
df
# Out:
#      CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]

# %%
df.plot.scatter(x='Annual Income (k$)',y='Spending Score (1-100)')
plt.show()

# %%
from sklearn.cluster import KMeans

# %%
X = df[['Annual Income (k$)','Spending Score (1-100)']]

# %%
wcss = []
for k in range(1,11):
    model = KMeans(n_clusters=k)
    model.fit(X)
    wcss.append(model.inertia_)

# %%
plt.plot(range(1,11),wcss,'ro--')
plt.title("WCSS analysis")
# Out:
# Text(0.5, 1.0, 'WCSS analysis')

# %%
model = KMeans(n_clusters=5)
model.fit(X)
df['groups']=model.predict(X)

# %%
df.plot.scatter(x='Annual Income (k$)',
                y='Spending Score (1-100)',
                c='groups',
                cmap='rainbow',
                s=100,
                figsize=(13,8))
plt.show()

# %% [markdown]
# ## Age vs Spending Score

# %%
X = df[['Age','Spending Score (1-100)']]
wcss = []
for k in range(1,11):
    model = KMeans(n_clusters=k)
    model.fit(X)
    wcss.append(model.inertia_)
plt.plot(range(1,11),wcss,'ro--')
plt.title("WCSS analysis")
# Out:
# Text(0.5, 1.0, 'WCSS analysis')

# %%
model = KMeans(n_clusters=4)
model.fit(X)
df['agewisegroups']=model.predict(X)

# %%
df.plot.scatter(x='Age',
                y='Spending Score (1-100)',
                c='agewisegroups',
                cmap='rainbow',
                s=100,
                figsize=(13,8))
plt.show()

# %% [markdown]
# # age vs annual  income vs spending

# %%
X = df[['Age','Annual Income (k$)','Spending Score (1-100)']]
wcss = []
for k in range(1,11):
    model = KMeans(n_clusters=k)
    model.fit(X)
    wcss.append(model.inertia_)
plt.plot(range(1,11),wcss,'ro--')
plt.title("WCSS analysis")
# Out:
# Text(0.5, 1.0, 'WCSS analysis')

# %%
model = KMeans(n_clusters=6)
model.fit(X)
df['groupsB']=model.predict(X)

# %%
fig = px.scatter_3d(df ,x='Annual Income (k$)',y='Spending Score (1-100)',z='Age',color='groupsB' )
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="41676a99-5a2b-4a2a-9e23-61c0a03478a5" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("41676a99-5a2b-4a2a-9e23-61c0a03478a5")) {
#                     Plotly.newPlot(
#                         '41676a99-5a2b-4a2a-9e23-61c0a03478a5',
# ...
