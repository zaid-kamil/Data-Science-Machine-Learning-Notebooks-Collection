# %%
a = 'alphonso'

# %%
type(a)
# Out:
# str

# %%
b = "there is a way out"

# %%
type(b)
# Out:
# str

# %%
c = '''this is a multiline story for
kids who dont study single line sentences
by JK Rowling'''

# %%
len(a)
# Out:
# 8

# %%
len(c)
# Out:
# 84

# %%
print(c)
# Out:
# the is a multiline story for
# kids who dont study single line sentences
# by JK Rowling

# %%
a[0]
# Out:
# 'a'

# %%
a[2]
# Out:
# 'p'

# %%
c[-1]
# Out:
# 'g'

# %%
subc = c[0:25]

# %%
name = "Vijay Deenanath Chauhan"

# %%
name[:5]
# Out:
# 'Vijay'

# %%
name[6:-8]
# Out:
# 'Deenanath'

# %%
name[-15:-2]
# Out:
# 'enanath Chauh'

# %%
name[-7:len(name)]
# Out:
# 'Chauhan'

# %%
name[-7:]
# Out:
# 'Chauhan'

# %%
name[:]
# Out:
# 'Vijay Deenanath Chauhan'

# %%
name[:][:][:]
# Out:
# 'Vijay Deenanath Chauhan'

# %%
name[::-1] # reversed string
# Out:
# 'nahuahC htananeeD yajiV'

# %%
name[::2] # even indexes
# Out:
# 'VjyDeaahCahn'

# %%
name[1::2] # odd indexes
# Out:
# 'ia ennt hua'

# %%
print('mera naam h', name)
# Out:
# mera naam h Vijay Deenanath Chauhan

# %%
base =  3
exp = 4
total = 3**4

# %%
f"{base}^{exp} = {total}" # fstrings are advance formatting technique for output
# Out:
# '3^4 = 81'

# %%
print(f"{base}^{exp} = {total}") # best
# Out:
# 3^4 = 81

# %%
print(base,'^',exp,'=',total) # simple
# Out:
# 3 ^ 4 = 81

# %%
print(str(base)+'^'+str(exp)+' = '+str(total)) # old way
# Out:
# 3^4 = 81

# %% [markdown]
# # functions

# %%
c
# Out:
# 'this is a multiline story for\nkids who dont study single line sentences\nby JK Rowling'

# %%
c.count('i')
# Out:
# 8

# %%
c.count('hello')
# Out:
# 0

# %%
c.replace('i','a')
# Out:
# 'thas as a multalane story for\nkads who dont study sangle lane sentences\nby JK Rowlang'

# %%
c
# Out:
# 'this is a multiline story for\nkids who dont study single line sentences\nby JK Rowling'

# %%
out =  c.replace('i','a')
print(out)
# Out:
# thas as a multalane story for
# kads who dont study sangle lane sentences
# by JK Rowlang

# %%
c.replace('this','that')
# Out:
# 'that is a multiline story for\nkids who dont study single line sentences\nby JK Rowling'

# %%
c[::-1].replace('i','a',2)[::-1]
# Out:
# 'this is a multiline story for\nkids who dont study single lane sentences\nby JK Rowlang'

# %%
c.split()

# %%
sentence = 'In the jungle,lives a cat as large as a lion, and as deadly as a lion.'

# %%
sentence.split()
# Out:
# ['In',
#  'the',
#  'jungle,lives',
#  'a',
#  'cat',
#  'as',
#  'large',
#  'as',
#  'a',
#  'lion,',
#  'and',
#  'as',
#  'deadly',
#  'as',
#  'a',
#  'lion.']

# %%
sentence.split(',')
# Out:
# ['In the jungle',
#  'lives a cat as large as a lion',
#  ' and as deadly as a lion.']

# %%
# home work task
fulldata = ""
while True:
    line  = input('line >>>')
    if not line:
        break
    fulldata += line+"\n"
print(fulldata)
# Out:
# line >>>johnny johnny, yes papa
# line >>>eating sugar, yes papa
# line >>>good
# line >>>

# %%
fulldata.split()
# Out:
# ['johnny', 'johnny,', 'yes', 'papa', 'eating', 'sugar,', 'yes', 'papa', 'good']

# %%
broken_sentence = ['there','was','Jupiter','the','god of Greek culture']
full_sentence = ' '.join(broken_sentence)
print(full_sentence)
# Out:
# there was Jupiter the god of Greek culture

# %%
fs = full_sentence

# %%
fs.upper()
# Out:
# 'THERE WAS JUPITER THE GOD OF GREEK CULTURE'

# %%
fs_caps  = fs.upper()

# %%
fs.lower()
# Out:
# 'there was jupiter the god of greek culture'

# %%
fs.capitalize()
# Out:
# 'There was jupiter the god of greek culture'

# %%
fst = fs.title()

# %%
fst.swapcase()
# Out:
# 'tHERE wAS jUPITER tHE gOD oF gREEK cULTURE'

# %%
len(fs)
# Out:
# 42

# %%
name ='Zaid Kamil'

# %%
name
# Out:
# 'Zaid Kamil'

# %%
name.ljust(30)
# Out:
# 'Zaid Kamil                    '

# %%
name.rjust(30)
# Out:
# '                    Zaid Kamil'

# %%
name.center(30)
# Out:
# '          Zaid Kamil          '

# %%
for i in range(1,13,2):
    print((i* '&').center(13))
# Out:
#       &
#      &&&
#     &&&&&
#    &&&&&&&
#   &&&&&&&&&
#  &&&&&&&&&&&

# %%
for i,v in enumerate(range(1200,1211)):
    print(v,i,str(v**i).rjust(40))
# Out:
# 1200 0                                        1
# 1201 1                                     1201
# 1202 2                                  1444804
# 1203 3                               1740992427
# 1204 4                            2101386547456
# 1205 5                         2540593803753125
# 1206 6                      3076690757009633856
# 1207 7                   3732079536569712755143
# 1208 8                4534563357363115619516416
# 1209 9             5518699003253664464836967289
# 1210 10          6727499949325600092010000000000

# %%
fs
# Out:
# 'there was Jupiter the god of Greek culture'

# %%
fs.find('the ')
# Out:
# 18

# %%
fs.find('hi')
# Out:
# -1

# %%
last = fs.find('the',1)

# %%
fs.find('the',last+1)
# Out:
# -1

# %%
content = 'abc.jpg'
content.endswith('jpg')
# Out:
# True

# %%
content.endswith('png')
# Out:
# False

# %%
content.startswith('ab')
# Out:
# True

# %%
content.startswith('bn')
# Out:
# False

# %%
employee = "Mr. Raju"
if employee.startswith('Mr.'):
    print('Welcome, Mr. Raju')
else:
    print("Come in Raju")
# Out:
# Welcome, Mr. Raju

# %%
print('name => %20s , thanks'%(name))
# Out:
# name =>           Zaid Kamil , thanks

# %%
price =39.903490

# %%
print('%.2f is the cost of a mouse in dollars'%(price))
# Out:
# 39.90 is the cost of a mouse in dollars

# %%
print('%-4.1f is the cost of a mouse in dollars'%(price))
# Out:
# 39.9 is the cost of a mouse in dollars

# %%
import random
heroes = ['Ironman','Superman','Batman']
r = random.choice(heroes)
print(f'{r} is coming to rescue')
# Out:
# Superman is coming to rescue
