# %%
import os

# %%
files = os.listdir('/content/sample_data')

# %%
for name in files:
    print(name,'=>', name.endswith('.csv'))
# Out:
# anscombe.json => False
# README.md => False
# california_housing_train.csv => True
# mnist_test.csv => True
# mnist_train_small.csv => True
# california_housing_test.csv => True
